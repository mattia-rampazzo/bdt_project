# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests numpy pandas
# Out:
# Requirement already satisfied: openmeteo-requests in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (1.3.0)
# Requirement already satisfied: openmeteo-sdk>=1.4.0 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from openmeteo-requests) (1.18.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from openmeteo-requests) (2.32.3)
# Requirement already satisfied: flatbuffers>=24.0.0 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from openmeteo-sdk>=1.4.0->openmeteo-requests) (24.3.25)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests->openmeteo-requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests->openmeteo-requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests->openmeteo-requests) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests->openmeteo-requests) (2024.7.4)
# Requirement already satisfied: requests-cache in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: retry-requests in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: attrs>=21.2 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests-cache) (23.2.0)
# Requirement already satisfied: cattrs>=22.2 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests-cache) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests-cache) (4.2.2)
# Requirement already satisfied: requests>=2.22 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests-cache) (2.32.3)
# Requirement already satisfied: url-normalize>=1.4 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: urllib3>=1.25.5 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests-cache) (1.26.19)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from cattrs>=22.2->requests-cache) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from cattrs>=22.2->requests-cache) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests>=2.22->requests-cache) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests>=2.22->requests-cache) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from requests>=2.22->requests-cache) (2024.7.4)

# %% [markdown]
# Testing the API call code for a selected pool of municipalities

# %%
import openmeteo_requests
import requests_cache
import pandas as pd
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after=-1)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = openmeteo_requests.Client(session=retry_session)

# List of locations with their coordinates (latitude, longitude)
locations = [
    {"name": "Trento", "latitude": 46.0679, "longitude": 11.1211},
    {"name": "Bolzano", "latitude": 46.4983, "longitude": 11.3548},
    {"name": "Rovereto", "latitude": 45.8903, "longitude": 11.0372}
]

# Date range and variables for the API request
start_date = "2024-01-01"
end_date = "2024-10-30"
hourly_variables = [
    "temperature_2m", "relative_humidity_2m", "precipitation", "rain",
    "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high",
    "wind_speed_10m", "soil_temperature_0_to_7cm"
]

# Rounding rules for formatting and approximating the variables
rounding_rules = {
    'temperature_2m (°C)': 1,
    'relative_humidity_2m (%)': 0,
    'precipitation (mm)': 2,
    'rain (mm)': 2,
    'cloud_cover (%)': 0,
    'cloud_cover_low (%)': 0,
    'cloud_cover_mid (%)': 0,
    'cloud_cover_high (%)': 0,
    'wind_speed_10m (km/h)': 1,
    'soil_temperature_0_to_7cm (°C)': 1
}

# Loop through each location and retrieve weather data
for location in locations:
    print(f"Processing weather data for {location['name']}...")
    
    params = {
        "latitude": location["latitude"],
        "longitude": location["longitude"],
        "start_date": start_date,
        "end_date": end_date,
        "hourly": hourly_variables
    }
    
    responses = openmeteo.weather_api("https://archive-api.open-meteo.com/v1/archive", params=params)
    
    # Process response for the current location
    response = responses[0]
    hourly = response.Hourly()
    hourly_data = {
        "date": pd.date_range(
            start=pd.to_datetime(hourly.Time(), unit="s", utc=True),
            end=pd.to_datetime(hourly.TimeEnd(), unit="s", utc=True),
            freq=pd.Timedelta(seconds=hourly.Interval()),
            inclusive="left"
        )
    }
    for i, var in enumerate(hourly_variables):
        hourly_data[var] = hourly.Variables(i).ValuesAsNumpy()
    
    # Convert to DataFrame
    df = pd.DataFrame(data=hourly_data)
    
    # Rename columns to match the desired format
    rename_mapping = {
        'date': 'time',
        'temperature_2m': 'temperature_2m (°C)',
        'relative_humidity_2m': 'relative_humidity_2m (%)',
        'precipitation': 'precipitation (mm)',
        'rain': 'rain (mm)',
        'cloud_cover': 'cloud_cover (%)',
        'cloud_cover_low': 'cloud_cover_low (%)',
        'cloud_cover_mid': 'cloud_cover_mid (%)',
        'cloud_cover_high': 'cloud_cover_high (%)',
        'wind_speed_10m': 'wind_speed_10m (km/h)',
        'soil_temperature_0_to_7cm': 'soil_temperature_0_to_7cm (°C)'
    }
    df.rename(columns=rename_mapping, inplace=True)
    
    # Format the 'time' column
    df['time'] = pd.to_datetime(df['time']).dt.strftime('%Y-%m-%dT%H:%M')
    
    # Apply rounding rules
    for column, decimals in rounding_rules.items():
        if column in df.columns:
            if decimals == 0:
                # For integer columns, apply round and convert to int
                df[column] = df[column].round(decimals).astype(int)
            else:
                # For other columns, apply rounding with specified decimals
                df[column] = df[column].round(decimals)
    
    # Save the transformed dataset
    output_file = f"{location['name']}_weather.csv"
    df.to_csv(output_file, index=False)
    print(f"Weather data for {location['name']} saved to {output_file}")
# Out:
# Processing weather data for Trento...
# Weather data for Trento saved to Trento_weather.csv
# Processing weather data for Bolzano...
# Weather data for Bolzano saved to Bolzano_weather.csv
# Processing weather data for Rovereto...
# Weather data for Rovereto saved to Rovereto_weather.csv

# %%
# !pip install geopandas
import folium
import geopandas as gpd

# Carica il file GeoJSON delle regioni italiane
# Sostituisci 'italy_regions.geojson' con il percorso al tuo file GeoJSON
gdf = gpd.read_file('/Users/davidegiordani/Desktop/BGTFinalCrack/limits_IT_regions.geojson')

# Filtra per la regione Trentino-Alto Adige
trentino_alto_adige = gdf[gdf['reg_name'] == 'Trentino-Alto Adige/Südtirol']

# Ottieni il centroide per centrare la mappa
centroid = trentino_alto_adige.geometry.centroid.iloc[0]
map_center = [centroid.y, centroid.x]

# Crea la mappa centrata sul Trentino-Alto Adige
m = folium.Map(location=map_center, zoom_start=8)

# Aggiungi il contorno della regione alla mappa
folium.GeoJson(
    trentino_alto_adige,
    name='Trentino-Alto Adige',
    style_function=lambda feature: {
        'fillColor': 'blue',
        'color': 'blue',
        'weight': 2,
        'fillOpacity': 0.1,
    }
).add_to(m)

# Aggiungi i controlli per i livelli
folium.LayerControl().add_to(m)

# Salva la mappa come file HTML
m.save('trentino_alto_adige_map.html')
print("Mappa salvata come 'trentino_alto_adige_map.html'")
# Out:
# Requirement already satisfied: geopandas in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from pyogrio>=0.7.2->geopandas) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ds/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Mappa salvata come 'trentino_alto_adige_map.html'
# /var/folders/q2/9lh55t_s1k56_qhpfd2m00f80000gn/T/ipykernel_2493/1512707382.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = trentino_alto_adige.geometry.centroid.iloc[0]

# %%
import openmeteo_requests
import requests_cache
import pandas as pd
import json
from shapely.geometry import shape
import time
from retry_requests import retry
import os
import re

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after=-1)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = openmeteo_requests.Client(session=retry_session)

# Load the GeoJSON file with municipalities
municipalities_path = 'limits_IT_municipalities.geojson'
with open(municipalities_path, 'r') as file:
    geojson_data = json.load(file)

# Extract relevant municipalities in Trentino-Alto Adige and calculate centroids
municipality_data = []
for feature in geojson_data["features"]:
    properties = feature["properties"]
    geometry = feature["geometry"]
    
    # Filter for municipalities in Trentino-Alto Adige region
    if properties.get("reg_name") == "Trentino-Alto Adige/Südtirol":
        geom = shape(geometry)
        centroid = geom.centroid
        municipality_data.append({
            "name": properties["name"],
            "latitude": centroid.y,
            "longitude": centroid.x
        })

# Function to sanitize file names
def sanitize_filename(name):
    return re.sub(r'[^\w\-_\. ]', '_', name)

# Date range and variables for the API request
start_date = "2022-01-01"
end_date = "2024-05-30"
hourly_variables = [
    "temperature_2m", "relative_humidity_2m", "precipitation", "rain",
    "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high",
    "wind_speed_10m", "soil_temperature_0_to_7cm"
]

# Rounding rules for formatting and approximating the variables
rounding_rules = {
    'temperature_2m (°C)': 1,
    'relative_humidity_2m (%)': 0,
    'precipitation (mm)': 2,
    'rain (mm)': 2,
    'cloud_cover (%)': 0,
    'cloud_cover_low (%)': 0,
    'cloud_cover_mid (%)': 0,
    'cloud_cover_high (%)': 0,
    'wind_speed_10m (km/h)': 1,
    'soil_temperature_0_to_7cm (°C)': 1
}

# Start processing
current_index = 0  # Start from the first municipality
while current_index < len(municipality_data):
    municipality = municipality_data[current_index]
    latitude = municipality["latitude"]
    longitude = municipality["longitude"]
    name = municipality["name"]
    sanitized_name = sanitize_filename(name)  # Sanitize municipality name
    
    print(f"Processing weather data for municipality: {name} ({latitude}, {longitude})...")
    
    params = {
        "latitude": latitude,
        "longitude": longitude,
        "start_date": start_date,
        "end_date": end_date,
        "hourly": hourly_variables
    }
    
    try:
        # Make the API call
        responses = openmeteo.weather_api("https://archive-api.open-meteo.com/v1/archive", params=params)
        
        # Process the response
        response = responses[0]
        hourly = response.Hourly()
        hourly_data = {
            "date": pd.date_range(
                start=pd.to_datetime(hourly.Time(), unit="s", utc=True),
                end=pd.to_datetime(hourly.TimeEnd(), unit="s", utc=True),
                freq=pd.Timedelta(seconds=hourly.Interval()),
                inclusive="left"
            )
        }
        for i, var in enumerate(hourly_variables):
            hourly_data[var] = hourly.Variables(i).ValuesAsNumpy()
        
        # Convert to DataFrame
        df = pd.DataFrame(data=hourly_data)
        
        # Rename columns to match the desired format
        rename_mapping = {
            'date': 'time',
            'temperature_2m': 'temperature_2m (°C)',
            'relative_humidity_2m': 'relative_humidity_2m (%)',
            'precipitation': 'precipitation (mm)',
            'rain': 'rain (mm)',
            'cloud_cover': 'cloud_cover (%)',
            'cloud_cover_low': 'cloud_cover_low (%)',
            'cloud_cover_mid': 'cloud_cover_mid (%)',
            'cloud_cover_high': 'cloud_cover_high (%)',
            'wind_speed_10m': 'wind_speed_10m (km/h)',
            'soil_temperature_0_to_7cm': 'soil_temperature_0_to_7cm (°C)'
        }
        df.rename(columns=rename_mapping, inplace=True)
        
        # Format the 'time' column
        df['time'] = pd.to_datetime(df['time']).dt.strftime('%Y-%m-%dT%H:%M')
        
        # Apply rounding rules
        for column, decimals in rounding_rules.items():
            if column in df.columns:
                if decimals == 0:
                    df[column] = df[column].round(decimals).astype(int)
                else:
                    df[column] = df[column].round(decimals)
        
        # Ensure the output directory exists
        output_dir = "WeatherTrentinoAltoAdige2024"
        os.makedirs(output_dir, exist_ok=True)

        # Save the transformed dataset
        output_file = os.path.join(output_dir, f"{sanitized_name}_weather.csv")
        df.to_csv(output_file, index=False)
        print(f"Weather data for {name} saved to {output_file}")
        
        current_index += 1  # Move to the next municipality on success
    
    except Exception as e:
        error_message = str(e)
        print(f"Error for {name} ({latitude}, {longitude}): {error_message}")
        if "Minutely API request limit exceeded" in error_message:
            # Extract suggested wait time
            retry_wait_time = 60  # Default to 60 seconds
            if "one minute" in error_message:
                retry_wait_time = 60
            elif "minute" in error_message:
                try:
                    retry_wait_time = int(re.findall(r'(\d+)\s+minute', error_message)[0]) * 60
                except:
                    retry_wait_time = 120  # Fallback to 2 minutes
            
            print(f"Waiting for {retry_wait_time} seconds before retrying...")
            time.sleep(retry_wait_time)
            # Retry the same municipality
        else:
            # Skip municipality on other errors
            print(f"Skipping {name} due to unhandled error: {error_message}")
            current_index += 1
# Out:
# Processing weather data for municipality: Aldino/Aldein (46.359502055842874, 11.392560462182377)...
# Weather data for Aldino/Aldein saved to WeatherTrentinoAltoAdige2024/Aldino_Aldein_weather.csv
# Processing weather data for municipality: Andriano/Andrian (46.518480075940644, 11.232025774529575)...
# Weather data for Andriano/Andrian saved to WeatherTrentinoAltoAdige2024/Andriano_Andrian_weather.csv
# Processing weather data for municipality: Anterivo/Altrei (46.27956889820043, 11.368050808976268)...
# Weather data for Anterivo/Altrei saved to WeatherTrentinoAltoAdige2024/Anterivo_Altrei_weather.csv
# Processing weather data for municipality: Appiano sulla strada del vino/Eppan an der Weinstraße (46.467482496744346, 11.255986244457276)...
# Weather data for Appiano sulla strada del vino/Eppan an der Weinstraße saved to WeatherTrentinoAltoAdige2024/Appiano sulla strada del vino_Eppan an der Weinstraße_weather.csv
# Processing weather data for municipality: Avelengo/Hafling (46.659199348784504, 11.250164803634044)...
# Weather data for Avelengo/Hafling saved to WeatherTrentinoAltoAdige2024/Avelengo_Hafling_weather.csv
# Processing weather data for municipality: Badia/Abtei (46.58223389504704, 11.920465829514228)...
# Weather data for Badia/Abtei saved to WeatherTrentinoAltoAdige2024/Badia_Abtei_weather.csv
# Processing weather data for municipality: Barbiano/Barbian (46.60667742797099, 11.492364558928633)...
# Weather data for Barbiano/Barbian saved to WeatherTrentinoAltoAdige2024/Barbiano_Barbian_weather.csv
# Processing weather data for municipality: Borgo d'Anaunia (46.47328997624824, 11.138404151006927)...
# Error for Borgo d'Anaunia (46.47328997624824, 11.138404151006927): {'reason': 'Daily API request limit exceeded. Please try again tomorrow.', 'error': True}
# Skipping Borgo d'Anaunia due to unhandled error: {'reason': 'Daily API request limit exceeded. Please try again tomorrow.', 'error': True}
# Processing weather data for municipality: Novella (46.431030150676705, 11.07088656304762)...
# Error for Novella (46.431030150676705, 11.07088656304762): {'reason': 'Daily API request limit exceeded. Please try again tomorrow.', 'error': True}
# Skipping Novella due to unhandled error: {'reason': 'Daily API request limit exceeded. Please try again tomorrow.', 'error': True}
# Processing weather data for municipality: Ville di Fiemme (46.317570655802214, 11.448899424596698)...
# Error for Ville di Fiemme (46.317570655802214, 11.448899424596698): {'reason': 'Daily API request limit exceeded. Please try again tomorrow.', 'error': True}
# Skipping Ville di Fiemme due to unhandled error: {'reason': 'Daily API request limit exceeded. Please try again tomorrow.', 'error': True}

# %%
import os

folder_path = '/Users/davidegiordani/Desktop/BGTFinalCrack/WeatherTrentinoAltoAdige2024'
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
csv_count = len(csv_files)

print(f"Number of .csv files in the folder: {csv_count}")
# Out:
# Number of .csv files in the folder: 249

# %% [markdown]
# The gathered data using the geojson file where not enough to build a solid model, so by using ChatGPT and other online sources I fetched the coordinates of the municipalities of each valley and presened them in the file called 'Merged_Valleys_and_Municipalities.csv', although this file may not contain all the municipalities for each valley of the region Trentino Alto Adige, and neither all the valleys, it i enough to have a structured model with a good amount of municipalities and also with the major valleys of the region that then will be levaraged to gather the data and build the predictions models.

# %%
import openmeteo_requests
import requests_cache
import pandas as pd
import json
from shapely.geometry import shape
import time
from retry_requests import retry
import os
import re

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after=-1)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = openmeteo_requests.Client(session=retry_session)

# Load the CSV file with municipalities
municipalities_path = 'TrentinoAltoAdigeZoneMapping/Final/Merged_Valleys_and_Municipalities.csv'
data = pd.read_csv(municipalities_path)
data.columns = data.columns.str.strip()  # Strip any whitespace from column names

# Extract relevant municipalities and their coordinates
municipality_data = []
for _, row in data.iterrows():
    municipality_data.append({
        "name": row["normalized_municipality"],
        "latitude": row["latitude"],
        "longitude": row["longitude"]
    })

# Function to sanitize file names
def sanitize_filename(name):
    return re.sub(r'[^\w\-_\. ]', '_', name)

# Date range and variables for the API request
start_date = "2022-01-01"
end_date = "2024-05-30"
hourly_variables = [
    "temperature_2m", "relative_humidity_2m", "precipitation", "rain",
    "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high",
    "wind_speed_10m", "soil_temperature_0_to_7cm"
]

# Rounding rules for formatting and approximating the variables
rounding_rules = {
    'temperature_2m (°C)': 1,
    'relative_humidity_2m (%)': 0,
    'precipitation (mm)': 2,
    'rain (mm)': 2,
    'cloud_cover (%)': 0,
    'cloud_cover_low (%)': 0,
    'cloud_cover_mid (%)': 0,
    'cloud_cover_high (%)': 0,
    'wind_speed_10m (km/h)': 1,
    'soil_temperature_0_to_7cm (°C)': 1
}

# Start processing
current_index = 0  # Start from the first municipality
while current_index < len(municipality_data):
    municipality = municipality_data[current_index]
    latitude = municipality["latitude"]
    longitude = municipality["longitude"]
    name = municipality["name"]
    sanitized_name = sanitize_filename(name)  # Sanitize municipality name
    
    print(f"Processing weather data for municipality: {name} ({latitude}, {longitude})...")
    
    params = {
        "latitude": latitude,
        "longitude": longitude,
        "start_date": start_date,
        "end_date": end_date,
        "hourly": hourly_variables
    }
    
    try:
        # Make the API call
        responses = openmeteo.weather_api("https://archive-api.open-meteo.com/v1/archive", params=params)
        
        # Process the response
        response = responses[0]
        hourly = response.Hourly()
        hourly_data = {
            "date": pd.date_range(
                start=pd.to_datetime(hourly.Time(), unit="s", utc=True),
                end=pd.to_datetime(hourly.TimeEnd(), unit="s", utc=True),
                freq=pd.Timedelta(seconds=hourly.Interval()),
                inclusive="left"
            )
        }
        for i, var in enumerate(hourly_variables):
            hourly_data[var] = hourly.Variables(i).ValuesAsNumpy()
        
        # Convert to DataFrame
        df = pd.DataFrame(data=hourly_data)
        
        # Rename columns to match the desired format
        rename_mapping = {
            'date': 'time',
            'temperature_2m': 'temperature_2m (°C)',
            'relative_humidity_2m': 'relative_humidity_2m (%)',
            'precipitation': 'precipitation (mm)',
            'rain': 'rain (mm)',
            'cloud_cover': 'cloud_cover (%)',
            'cloud_cover_low': 'cloud_cover_low (%)',
            'cloud_cover_mid': 'cloud_cover_mid (%)',
            'cloud_cover_high': 'cloud_cover_high (%)',
            'wind_speed_10m': 'wind_speed_10m (km/h)',
            'soil_temperature_0_to_7cm': 'soil_temperature_0_to_7cm (°C)'
        }
        df.rename(columns=rename_mapping, inplace=True)
        
        # Format the 'time' column
        df['time'] = pd.to_datetime(df['time']).dt.strftime('%Y-%m-%dT%H:%M')
        
        # Apply rounding rules
        for column, decimals in rounding_rules.items():
            if column in df.columns:
                if decimals == 0:
                    df[column] = df[column].round(decimals).astype(int)
                else:
                    df[column] = df[column].round(decimals)
        
        # Ensure the output directory exists
        output_dir = "WeatherTrentinoAltoAdige2024"
        os.makedirs(output_dir, exist_ok=True)

        # Save the transformed dataset
        output_file = os.path.join(output_dir, f"{sanitized_name}_weather.csv")
        df.to_csv(output_file, index=False)
        print(f"Weather data for {name} saved to {output_file}")
        
        current_index += 1  # Move to the next municipality on success
    
    except Exception as e:
        error_message = str(e)
        print(f"Error for {name} ({latitude}, {longitude}): {error_message}")
        if "Minutely API request limit exceeded" in error_message:
            # Extract suggested wait time
            retry_wait_time = 60  # Default to 60 seconds
            if "one minute" in error_message:
                retry_wait_time = 60
            elif "minute" in error_message:
                try:
                    retry_wait_time = int(re.findall(r'(\d+)\s+minute', error_message)[0]) * 60
                except:
                    retry_wait_time = 120  # Fallback to 2 minutes
            
            print(f"Waiting for {retry_wait_time} seconds before retrying...")
            time.sleep(retry_wait_time)
            # Retry the same municipality
        else:
            # Skip municipality on other errors
# Weather data for anterivo saved to WeatherTrentinoAltoAdige2024/anterivo_weather.csv
# Processing weather data for municipality: appiano sulla strada del vino (46.467482496744346, 11.255986244457276)...
# Weather data for appiano sulla strada del vino saved to WeatherTrentinoAltoAdige2024/appiano sulla strada del vino_weather.csv
# Processing weather data for municipality: appiano sulla strada del vino (46.467482496744346, 11.255986244457276)...
# Weather data for appiano sulla strada del vino saved to WeatherTrentinoAltoAdige2024/appiano sulla strada del vino_weather.csv
# Processing weather data for municipality: arco (45.929509015373, 10.905961016739688)...
# Weather data for arco saved to WeatherTrentinoAltoAdige2024/arco_weather.csv
# Processing weather data for municipality: auer (46.36295424541759, 11.30525325050825)...
# Weather data for auer saved to WeatherTrentinoAltoAdige2024/auer_weather.csv
# Processing weather data for municipality: avelengo (46.659199348784504, 11.250164803634044)...
# Weather data for avelengo saved to WeatherTrentinoAltoAdige2024/avelengo_weather.csv
# Processing weather data for municipality: avelengo (46.659199348784504, 11.250164803634044)...
# Weather data for avelengo saved to WeatherTrentinoAltoAdige2024/avelengo_weather.csv
# Processing weather data for municipality: avio (45.732061463822966, 10.918992209378915)...
# Weather data for avio saved to WeatherTrentinoAltoAdige2024/avio_weather.csv
# Processing weather data for municipality: badia (46.58223389504704, 11.920465829514228)...
# Weather data for badia saved to WeatherTrentinoAltoAdige2024/badia_weather.csv
# Processing weather data for municipality: badia (46.58223389504704, 11.920465829514228)...
# Weather data for badia saved to WeatherTrentinoAltoAdige2024/badia_weather.csv
# Processing weather data for municipality: barbian (46.60667742797099, 11.492364558928632)...
# Weather data for barbian saved to WeatherTrentinoAltoAdige2024/barbian_weather.csv
# Processing weather data for municipality: barbiano (46.60667742797099, 11.492364558928632)...
# Weather data for barbiano saved to WeatherTrentinoAltoAdige2024/barbiano_weather.csv
# Processing weather data for municipality: barbiano (46.60667742797099, 11.492364558928632)...
# Weather data for barbiano saved to WeatherTrentinoAltoAdige2024/barbiano_weather.csv
# Processing weather data for municipality: baselga di pine (46.1406879585565, 11.281807687187293)...
# Weather data for baselga di pine saved to WeatherTrentinoAltoAdige2024/baselga di pine_weather.csv
# Processing weather data for municipality: baselga di pine (46.1406879585565, 11.281807687187293)...
# Weather data for baselga di pine saved to WeatherTrentinoAltoAdige2024/baselga di pine_weather.csv
# Processing weather data for municipality: bedollo (46.16447904708729, 11.316476071505583)...
# Weather data for bedollo saved to WeatherTrentinoAltoAdige2024/bedollo_weather.csv
# Processing weather data for municipality: besenello (45.952752348819274, 11.14230081802822)...
# Weather data for besenello saved to WeatherTrentinoAltoAdige2024/besenello_weather.csv
# Processing weather data for municipality: bezzecca (45.9167, 10.7333)...
# Weather data for bezzecca saved to WeatherTrentinoAltoAdige2024/bezzecca_weather.csv
# Processing weather data for municipality: bieno (46.09808695914107, 11.562943544429952)...
# Weather data for bieno saved to WeatherTrentinoAltoAdige2024/bieno_weather.csv
# Processing weather data for municipality: bleggio superiore (46.009884367595966, 10.793310640088237)...
# Weather data for bleggio superiore saved to WeatherTrentinoAltoAdige2024/bleggio superiore_weather.csv
# Processing weather data for municipality: campitello di fassa (46.49055187484705, 11.711891049532491)...
# Weather data for campitello di fassa saved to WeatherTrentinoAltoAdige2024/campitello di fassa_weather.csv
# Processing weather data for municipality: campitello di fassa (46.49055187484705, 11.711891049532491)...
# Weather data for campitello di fassa saved to WeatherTrentinoAltoAdige2024/campitello di fassa_weather.csv
# Processing weather data for municipality: campo di trens (46.858879791271136, 11.510328942027607)...
# Weather data for campo di trens saved to WeatherTrentinoAltoAdige2024/campo di trens_weather.csv
# Processing weather data for municipality: campo di trens (46.858879791271136, 11.510328942027607)...
# Weather data for campo di trens saved to WeatherTrentinoAltoAdige2024/campo di trens_weather.csv
# Processing weather data for municipality: campo di trens (46.858879791271136, 11.510328942027607)...
# Weather data for campo di trens saved to WeatherTrentinoAltoAdige2024/campo di trens_weather.csv
# Processing weather data for municipality: campo tures (46.93081305923854, 12.037953028355764)...
# Weather data for campo tures saved to WeatherTrentinoAltoAdige2024/campo tures_weather.csv
# Processing weather data for municipality: campodenno (46.247261828106346, 11.00184920636394)...
# Weather data for campodenno saved to WeatherTrentinoAltoAdige2024/campodenno_weather.csv
# Processing weather data for municipality: canal san bovo (46.199195922350285, 11.700089354752842)...
# Weather data for canal san bovo saved to WeatherTrentinoAltoAdige2024/canal san bovo_weather.csv
# Processing weather data for municipality: canazei (46.46960280421649, 11.81089758714613)...
# Weather data for canazei saved to WeatherTrentinoAltoAdige2024/canazei_weather.csv
# Processing weather data for municipality: canazei (46.46960280421649, 11.81089758714613)...
# Weather data for canazei saved to WeatherTrentinoAltoAdige2024/canazei_weather.csv
# Processing weather data for municipality: capriana (46.27031303806913, 11.330894556121551)...
# Weather data for capriana saved to WeatherTrentinoAltoAdige2024/capriana_weather.csv
# Processing weather data for municipality: carano (46.2833, 11.45)...
# Weather data for carano saved to WeatherTrentinoAltoAdige2024/carano_weather.csv
# Processing weather data for municipality: carisolo (46.20396237924361, 10.731512487155811)...
# Weather data for carisolo saved to WeatherTrentinoAltoAdige2024/carisolo_weather.csv
# Processing weather data for municipality: carzano (46.07496621778164, 11.494361873193396)...
# Weather data for carzano saved to WeatherTrentinoAltoAdige2024/carzano_weather.csv
# Processing weather data for municipality: castel condino (45.92231949316601, 10.586179140280697)...
# Weather data for castel condino saved to WeatherTrentinoAltoAdige2024/castel condino_weather.csv
# Processing weather data for municipality: castel ivano (46.065267667976954, 11.535313338742194)...
# Weather data for castel ivano saved to WeatherTrentinoAltoAdige2024/castel ivano_weather.csv
# Processing weather data for municipality: castelbello-ciardes (46.625783161535075, 10.929184789354707)...
# Weather data for castelbello-ciardes saved to WeatherTrentinoAltoAdige2024/castelbello-ciardes_weather.csv
# Processing weather data for municipality: castelbello-ciardes (46.625783161535075, 10.929184789354707)...
# Weather data for castelbello-ciardes saved to WeatherTrentinoAltoAdige2024/castelbello-ciardes_weather.csv
# Processing weather data for municipality: castelfondo (46.4315, 11.0662)...
# Weather data for castelfondo saved to WeatherTrentinoAltoAdige2024/castelfondo_weather.csv
# Processing weather data for municipality: castello tesino (46.12108546659756, 11.645748269814108)...
# Weather data for castello tesino saved to WeatherTrentinoAltoAdige2024/castello tesino_weather.csv
# Processing weather data for municipality: castello-molina di fiemme (46.22596643108608, 11.432768885557902)...
# Weather data for castello-molina di fiemme saved to WeatherTrentinoAltoAdige2024/castello-molina di fiemme_weather.csv
# Processing weather data for municipality: castelnuovo (46.0375898778649, 11.49462945520579)...
# Weather data for castelnuovo saved to WeatherTrentinoAltoAdige2024/castelnuovo_weather.csv
# Processing weather data for municipality: castelrotto (46.54644795338484, 11.6127445781557)...
# Weather data for castelrotto saved to WeatherTrentinoAltoAdige2024/castelrotto_weather.csv
# Processing weather data for municipality: castelrotto (46.54644795338484, 11.6127445781557)...
# Weather data for castelrotto saved to WeatherTrentinoAltoAdige2024/castelrotto_weather.csv
# Processing weather data for municipality: cavalese (46.247840861770506, 11.474430012096384)...
# Weather data for cavalese saved to WeatherTrentinoAltoAdige2024/cavalese_weather.csv
# Processing weather data for municipality: cavareno (46.40666098853849, 11.172702088389434)...
# Weather data for cavareno saved to WeatherTrentinoAltoAdige2024/cavareno_weather.csv
# Processing weather data for municipality: cavedago (46.183871433181736, 11.009170691741458)...
# Weather data for cavedago saved to WeatherTrentinoAltoAdige2024/cavedago_weather.csv
# Processing weather data for municipality: cavedine (45.98601746554015, 10.98915107338422)...
# Weather data for cavedine saved to WeatherTrentinoAltoAdige2024/cavedine_weather.csv
# Processing weather data for municipality: cavizzana (46.3640311149963, 10.964275713104978)...
# Weather data for cavizzana saved to WeatherTrentinoAltoAdige2024/cavizzana_weather.csv
# Processing weather data for municipality: cembra lisignago (46.18286774215116, 11.205780323254682)...
# Weather data for cembra lisignago saved to WeatherTrentinoAltoAdige2024/cembra lisignago_weather.csv
# Processing weather data for municipality: cermes (46.63375781246668, 11.136403050510523)...
# Weather data for cermes saved to WeatherTrentinoAltoAdige2024/cermes_weather.csv
# Processing weather data for municipality: chienes (46.814377328528195, 11.823483914309303)...
# Weather data for chienes saved to WeatherTrentinoAltoAdige2024/chienes_weather.csv
# Processing weather data for municipality: chienes (46.814377328528195, 11.823483914309303)...
# Weather data for chienes saved to WeatherTrentinoAltoAdige2024/chienes_weather.csv
# Processing weather data for municipality: chiusa (46.671168832353835, 11.53991319628849)...
# Weather data for chiusa saved to WeatherTrentinoAltoAdige2024/chiusa_weather.csv
# Processing weather data for municipality: chiusa (46.671168832353835, 11.53991319628849)...
# Weather data for chiusa saved to WeatherTrentinoAltoAdige2024/chiusa_weather.csv
# Processing weather data for municipality: cimego (45.9761, 10.6713)...
# Weather data for cimego saved to WeatherTrentinoAltoAdige2024/cimego_weather.csv
# Processing weather data for municipality: cimone (45.979737105296635, 11.059239122158502)...
# Weather data for cimone saved to WeatherTrentinoAltoAdige2024/cimone_weather.csv
# Processing weather data for municipality: cinte tesino (46.0930830834456, 11.653249596393948)...
# Weather data for cinte tesino saved to WeatherTrentinoAltoAdige2024/cinte tesino_weather.csv
# Processing weather data for municipality: cis (46.401079458369736, 10.992288494870412)...
# Weather data for cis saved to WeatherTrentinoAltoAdige2024/cis_weather.csv
# Processing weather data for municipality: civezzano (46.10108620842407, 11.180553177264777)...
# Weather data for civezzano saved to WeatherTrentinoAltoAdige2024/civezzano_weather.csv
# Processing weather data for municipality: civezzano (46.10108620842407, 11.180553177264777)...
# Weather data for civezzano saved to WeatherTrentinoAltoAdige2024/civezzano_weather.csv
# Processing weather data for municipality: cles (46.34690937398706, 10.98899822652013)...
# Weather data for cles saved to WeatherTrentinoAltoAdige2024/cles_weather.csv
# Processing weather data for municipality: cloz (46.4167, 11.0833)...
# Weather data for cloz saved to WeatherTrentinoAltoAdige2024/cloz_weather.csv
# Processing weather data for municipality: comano terme (46.04552467822622, 10.862117090411129)...
# Weather data for comano terme saved to WeatherTrentinoAltoAdige2024/comano terme_weather.csv
# Processing weather data for municipality: commezzadura (46.313866163748706, 10.837731088950402)...
# Weather data for commezzadura saved to WeatherTrentinoAltoAdige2024/commezzadura_weather.csv
# Processing weather data for municipality: concei (45.9, 10.75)...
# Weather data for concei saved to WeatherTrentinoAltoAdige2024/concei_weather.csv
# Processing weather data for municipality: condino (45.9516, 10.6182)...
# Weather data for condino saved to WeatherTrentinoAltoAdige2024/condino_weather.csv
# Processing weather data for municipality: conta (46.29510326662769, 11.018268660466546)...
# Weather data for conta saved to WeatherTrentinoAltoAdige2024/conta_weather.csv
# Processing weather data for municipality: coredo (46.3667, 11.1167)...
# Weather data for coredo saved to WeatherTrentinoAltoAdige2024/coredo_weather.csv
# Processing weather data for municipality: cornedo allisarco (46.466245729829545, 11.462276904388345)...
# Weather data for cornedo allisarco saved to WeatherTrentinoAltoAdige2024/cornedo allisarco_weather.csv
# Processing weather data for municipality: cornedo allisarco (46.466245729829545, 11.462276904388345)...
# Weather data for cornedo allisarco saved to WeatherTrentinoAltoAdige2024/cornedo allisarco_weather.csv
# Processing weather data for municipality: cornedo allisarco (46.466245729829545, 11.462276904388345)...
# Weather data for cornedo allisarco saved to WeatherTrentinoAltoAdige2024/cornedo allisarco_weather.csv
# Processing weather data for municipality: cortaccia sulla strada del vino (46.305175245274725, 11.200787096397724)...
# Weather data for cortaccia sulla strada del vino saved to WeatherTrentinoAltoAdige2024/cortaccia sulla strada del vino_weather.csv
# Processing weather data for municipality: cortaccia sulla strada del vino (46.305175245274725, 11.200787096397724)...
# Weather data for cortaccia sulla strada del vino saved to WeatherTrentinoAltoAdige2024/cortaccia sulla strada del vino_weather.csv
# Processing weather data for municipality: cortaccia sulla strada del vino (46.305175245274725, 11.200787096397724)...
# Weather data for cortaccia sulla strada del vino saved to WeatherTrentinoAltoAdige2024/cortaccia sulla strada del vino_weather.csv
# Processing weather data for municipality: cortina sulla strada del vino (46.26621056074566, 11.22285004384062)...
# Weather data for cortina sulla strada del vino saved to WeatherTrentinoAltoAdige2024/cortina sulla strada del vino_weather.csv
# Processing weather data for municipality: cortina sulla strada del vino (46.26621056074566, 11.22285004384062)...
# Weather data for cortina sulla strada del vino saved to WeatherTrentinoAltoAdige2024/cortina sulla strada del vino_weather.csv
# Processing weather data for municipality: cortina sulla strada del vino (46.26621056074566, 11.22285004384062)...
# Weather data for dro saved to WeatherTrentinoAltoAdige2024/dro_weather.csv
# Processing weather data for municipality: dro (45.99027535012607, 10.923697976350937)...
# Weather data for dro saved to WeatherTrentinoAltoAdige2024/dro_weather.csv
# Processing weather data for municipality: egna (46.29569221039571, 11.269313365625026)...
# Weather data for egna saved to WeatherTrentinoAltoAdige2024/egna_weather.csv
# Processing weather data for municipality: egna (46.29569221039571, 11.269313365625026)...
# Weather data for egna saved to WeatherTrentinoAltoAdige2024/egna_weather.csv
# Processing weather data for municipality: enneberg (46.66529529402627, 11.97409794065717)...
# Weather data for enneberg saved to WeatherTrentinoAltoAdige2024/enneberg_weather.csv
# Processing weather data for municipality: eppan an der weinstrae (46.467482496744346, 11.255986244457276)...
# Weather data for eppan an der weinstrae saved to WeatherTrentinoAltoAdige2024/eppan an der weinstrae_weather.csv
# Processing weather data for municipality: faedo (46.1932, 11.1583)...
# Weather data for faedo saved to WeatherTrentinoAltoAdige2024/faedo_weather.csv
# Processing weather data for municipality: fai della paganella (46.17747491598849, 11.060749926325457)...
# Weather data for fai della paganella saved to WeatherTrentinoAltoAdige2024/fai della paganella_weather.csv
# Processing weather data for municipality: falzes (46.830583502213926, 11.879381695444168)...
# Weather data for falzes saved to WeatherTrentinoAltoAdige2024/falzes_weather.csv
# Processing weather data for municipality: falzes (46.830583502213926, 11.879381695444168)...
# Weather data for falzes saved to WeatherTrentinoAltoAdige2024/falzes_weather.csv
# Processing weather data for municipality: faver (46.2, 11.2833)...
# Weather data for faver saved to WeatherTrentinoAltoAdige2024/faver_weather.csv
# Processing weather data for municipality: feldthurns (46.684878627429434, 11.585481136611367)...
# Weather data for feldthurns saved to WeatherTrentinoAltoAdige2024/feldthurns_weather.csv
# Processing weather data for municipality: fiave (45.98535686061111, 10.820172680279056)...
# Weather data for fiave saved to WeatherTrentinoAltoAdige2024/fiave_weather.csv
# Processing weather data for municipality: fie allo sciliar (46.50802705505989, 11.520169281625666)...
# Weather data for fie allo sciliar saved to WeatherTrentinoAltoAdige2024/fie allo sciliar_weather.csv
# Processing weather data for municipality: fie allo sciliar (46.50802705505989, 11.520169281625666)...
# Weather data for fie allo sciliar saved to WeatherTrentinoAltoAdige2024/fie allo sciliar_weather.csv
# Processing weather data for municipality: fiera di primiero (46.1721, 11.8511)...
# Weather data for fiera di primiero saved to WeatherTrentinoAltoAdige2024/fiera di primiero_weather.csv
# Processing weather data for municipality: fierozzo (46.10557548256564, 11.342158234611558)...
# Weather data for fierozzo saved to WeatherTrentinoAltoAdige2024/fierozzo_weather.csv
# Processing weather data for municipality: flavon (46.3167, 11.0667)...
# Weather data for flavon saved to WeatherTrentinoAltoAdige2024/flavon_weather.csv
# Processing weather data for municipality: folgaria (45.908779905847766, 11.199106310628531)...
# Weather data for folgaria saved to WeatherTrentinoAltoAdige2024/folgaria_weather.csv
# Processing weather data for municipality: fondo (46.45, 11.1333)...
# Weather data for fondo saved to WeatherTrentinoAltoAdige2024/fondo_weather.csv
# Processing weather data for municipality: fornace (46.12232094425691, 11.20558641009664)...
# Weather data for fornace saved to WeatherTrentinoAltoAdige2024/fornace_weather.csv
# Processing weather data for municipality: fornace (46.12232094425691, 11.20558641009664)...
# Weather data for fornace saved to WeatherTrentinoAltoAdige2024/fornace_weather.csv
# Processing weather data for municipality: fortezza (46.799032268508334, 11.5586746773434)...
# Weather data for fortezza saved to WeatherTrentinoAltoAdige2024/fortezza_weather.csv
# Processing weather data for municipality: fortezza (46.799032268508334, 11.5586746773434)...
# Weather data for fortezza saved to WeatherTrentinoAltoAdige2024/fortezza_weather.csv
# Processing weather data for municipality: fortezza (46.799032268508334, 11.5586746773434)...
# Weather data for fortezza saved to WeatherTrentinoAltoAdige2024/fortezza_weather.csv
# Processing weather data for municipality: franzensfeste (46.799032268508334, 11.5586746773434)...
# Weather data for franzensfeste saved to WeatherTrentinoAltoAdige2024/franzensfeste_weather.csv
# Processing weather data for municipality: frassilongo (46.07615763037611, 11.316421231511615)...
# Weather data for frassilongo saved to WeatherTrentinoAltoAdige2024/frassilongo_weather.csv
# Processing weather data for municipality: freienfeld (46.858879791271136, 11.510328942027607)...
# Weather data for freienfeld saved to WeatherTrentinoAltoAdige2024/freienfeld_weather.csv
# Processing weather data for municipality: funes (46.63948488798519, 11.713404571230734)...
# Weather data for funes saved to WeatherTrentinoAltoAdige2024/funes_weather.csv
# Processing weather data for municipality: funes (46.63948488798519, 11.713404571230734)...
# Weather data for funes saved to WeatherTrentinoAltoAdige2024/funes_weather.csv
# Processing weather data for municipality: gais (46.8573706019335, 11.978925811470663)...
# Weather data for gais saved to WeatherTrentinoAltoAdige2024/gais_weather.csv
# Processing weather data for municipality: gais (46.8573706019335, 11.978925811470663)...
# Weather data for gais saved to WeatherTrentinoAltoAdige2024/gais_weather.csv
# Processing weather data for municipality: gais (46.8573706019335, 11.978925811470663)...
# Weather data for gais saved to WeatherTrentinoAltoAdige2024/gais_weather.csv
# Processing weather data for municipality: gais (46.8573706019335, 11.978925811470663)...
# Weather data for gais saved to WeatherTrentinoAltoAdige2024/gais_weather.csv
# Processing weather data for municipality: gais (46.8573706019335, 11.978925811470663)...
# Weather data for gais saved to WeatherTrentinoAltoAdige2024/gais_weather.csv
# Processing weather data for municipality: gais (46.8573706019335, 11.978925811470663)...
# Weather data for gais saved to WeatherTrentinoAltoAdige2024/gais_weather.csv
# Processing weather data for municipality: gargazon (46.5774163650477, 11.20279902653723)...
# Weather data for gargazon saved to WeatherTrentinoAltoAdige2024/gargazon_weather.csv
# Processing weather data for municipality: gargazzone (46.5774163650477, 11.20279902653723)...
# Weather data for gargazzone saved to WeatherTrentinoAltoAdige2024/gargazzone_weather.csv
# Processing weather data for municipality: gargazzone (46.5774163650477, 11.20279902653723)...
# Weather data for gargazzone saved to WeatherTrentinoAltoAdige2024/gargazzone_weather.csv
# Processing weather data for municipality: garniga terme (46.005377805316826, 11.07311406712547)...
# Weather data for garniga terme saved to WeatherTrentinoAltoAdige2024/garniga terme_weather.csv
# Processing weather data for municipality: giovo (46.17908718847846, 11.160861480273846)...
# Weather data for giovo saved to WeatherTrentinoAltoAdige2024/giovo_weather.csv
# Processing weather data for municipality: giustino (46.190290418627065, 10.714618575519086)...
# Weather data for giustino saved to WeatherTrentinoAltoAdige2024/giustino_weather.csv
# Processing weather data for municipality: glorenza (46.656141740360766, 10.545729074189822)...
# Weather data for glorenza saved to WeatherTrentinoAltoAdige2024/glorenza_weather.csv
# Processing weather data for municipality: glorenza (46.656141740360766, 10.545729074189822)...
# Weather data for glorenza saved to WeatherTrentinoAltoAdige2024/glorenza_weather.csv
# Processing weather data for municipality: glurns (46.656141740360766, 10.545729074189822)...
# Weather data for glurns saved to WeatherTrentinoAltoAdige2024/glurns_weather.csv
# Processing weather data for municipality: graun im vinschgau (46.80885800769775, 10.57954528766676)...
# Weather data for graun im vinschgau saved to WeatherTrentinoAltoAdige2024/graun im vinschgau_weather.csv
# Processing weather data for municipality: grauno (46.2167, 11.3167)...
# Weather data for grauno saved to WeatherTrentinoAltoAdige2024/grauno_weather.csv
# Processing weather data for municipality: grigno (45.99381231121521, 11.632537731060774)...
# Weather data for grigno saved to WeatherTrentinoAltoAdige2024/grigno_weather.csv
# Processing weather data for municipality: grumes (46.2167, 11.3167)...
# Weather data for grumes saved to WeatherTrentinoAltoAdige2024/grumes_weather.csv
# Processing weather data for municipality: gsies (46.820949309310905, 12.225261029082036)...
# Weather data for gsies saved to WeatherTrentinoAltoAdige2024/gsies_weather.csv
# Processing weather data for municipality: hafling (46.659199348784504, 11.250164803634044)...
# Weather data for hafling saved to WeatherTrentinoAltoAdige2024/hafling_weather.csv
# Processing weather data for municipality: iavre (46.05, 10.7)...
# Weather data for iavre saved to WeatherTrentinoAltoAdige2024/iavre_weather.csv
# Processing weather data for municipality: imer (46.150220124838334, 11.786624916757896)...
# Weather data for imer saved to WeatherTrentinoAltoAdige2024/imer_weather.csv
# Processing weather data for municipality: imer (46.1667, 11.8333)...
# Weather data for imer saved to WeatherTrentinoAltoAdige2024/imer_weather.csv
# Processing weather data for municipality: imer (46.150220124838334, 11.786624916757896)...
# Weather data for imer saved to WeatherTrentinoAltoAdige2024/imer_weather.csv
# Processing weather data for municipality: imer (46.1667, 11.8333)...
# Weather data for imer saved to WeatherTrentinoAltoAdige2024/imer_weather.csv
# Processing weather data for municipality: innichen (46.71359103123984, 12.307402244776725)...
# Weather data for innichen saved to WeatherTrentinoAltoAdige2024/innichen_weather.csv
# Processing weather data for municipality: isera (45.89300508248693, 10.996927893801448)...
# Weather data for isera saved to WeatherTrentinoAltoAdige2024/isera_weather.csv
# Processing weather data for municipality: ivano-fracena (46.05, 11.5)...
# Weather data for ivano-fracena saved to WeatherTrentinoAltoAdige2024/ivano-fracena_weather.csv
# Processing weather data for municipality: javre (46.05, 10.7)...
# Weather data for javre saved to WeatherTrentinoAltoAdige2024/javre_weather.csv
# Processing weather data for municipality: jenesien (46.56176473379593, 11.321780790425532)...
# Weather data for jenesien saved to WeatherTrentinoAltoAdige2024/jenesien_weather.csv
# Processing weather data for municipality: kaltern an der weinstrae (46.393771435297495, 11.245721745421651)...
# Weather data for kaltern an der weinstrae saved to WeatherTrentinoAltoAdige2024/kaltern an der weinstrae_weather.csv
# Processing weather data for municipality: karneid (46.466245729829545, 11.462276904388345)...
# Weather data for karneid saved to WeatherTrentinoAltoAdige2024/karneid_weather.csv
# Processing weather data for municipality: kastelbell-tschars (46.625783161535075, 10.929184789354707)...
# Weather data for kastelbell-tschars saved to WeatherTrentinoAltoAdige2024/kastelbell-tschars_weather.csv
# Processing weather data for municipality: kastelruth (46.54644795338484, 11.6127445781557)...
# Weather data for kastelruth saved to WeatherTrentinoAltoAdige2024/kastelruth_weather.csv
# Processing weather data for municipality: kiens (46.814377328528195, 11.823483914309303)...
# Weather data for kiens saved to WeatherTrentinoAltoAdige2024/kiens_weather.csv
# Processing weather data for municipality: klausen (46.671168832353835, 11.53991319628849)...
# Weather data for klausen saved to WeatherTrentinoAltoAdige2024/klausen_weather.csv
# Processing weather data for municipality: kuens (46.70115218454029, 11.169167248358608)...
# Weather data for kuens saved to WeatherTrentinoAltoAdige2024/kuens_weather.csv
# Processing weather data for municipality: kurtatsch an der weinstrae (46.305175245274725, 11.200787096397724)...
# Weather data for kurtatsch an der weinstrae saved to WeatherTrentinoAltoAdige2024/kurtatsch an der weinstrae_weather.csv
# Processing weather data for municipality: kurtatsch an der weinstrae (46.305175245274725, 11.200787096397724)...
# Weather data for kurtatsch an der weinstrae saved to WeatherTrentinoAltoAdige2024/kurtatsch an der weinstrae_weather.csv
# Processing weather data for municipality: kurtinig an der weinstrae (46.26621056074566, 11.22285004384062)...
# Weather data for kurtinig an der weinstrae saved to WeatherTrentinoAltoAdige2024/kurtinig an der weinstrae_weather.csv
# Processing weather data for municipality: kurtinig an der weinstrae (46.26621056074566, 11.22285004384062)...
# Weather data for kurtinig an der weinstrae saved to WeatherTrentinoAltoAdige2024/kurtinig an der weinstrae_weather.csv
# Processing weather data for municipality: la valle (46.6492925221126, 11.93849485863982)...
# Weather data for la valle saved to WeatherTrentinoAltoAdige2024/la valle_weather.csv
# Processing weather data for municipality: la valle (46.6492925221126, 11.93849485863982)...
# Weather data for la valle saved to WeatherTrentinoAltoAdige2024/la valle_weather.csv
# Processing weather data for municipality: laas (46.606038126534635, 10.668992009919512)...
# Weather data for laas saved to WeatherTrentinoAltoAdige2024/laas_weather.csv
# Processing weather data for municipality: laces (46.60094617858487, 10.85757429413232)...
# Weather data for laces saved to WeatherTrentinoAltoAdige2024/laces_weather.csv
# Processing weather data for municipality: laces (46.60094617858487, 10.85757429413232)...
# Weather data for laces saved to WeatherTrentinoAltoAdige2024/laces_weather.csv
# Processing weather data for municipality: lagolo (46.0167, 10.95)...
# Weather data for lagolo saved to WeatherTrentinoAltoAdige2024/lagolo_weather.csv
# Processing weather data for municipality: lagundo (46.67771621370486, 11.098784277418655)...
# Weather data for lagundo saved to WeatherTrentinoAltoAdige2024/lagundo_weather.csv
# Processing weather data for municipality: lagundo (46.67771621370486, 11.098784277418655)...
# Weather data for lagundo saved to WeatherTrentinoAltoAdige2024/lagundo_weather.csv
# Processing weather data for municipality: laion (46.6122023477098, 11.597114374080435)...
# Weather data for laion saved to WeatherTrentinoAltoAdige2024/laion_weather.csv
# Processing weather data for municipality: laion (46.6122023477098, 11.597114374080435)...
# Weather data for laion saved to WeatherTrentinoAltoAdige2024/laion_weather.csv
# Processing weather data for municipality: laives (46.438480091452206, 11.344890307571587)...
# Weather data for laives saved to WeatherTrentinoAltoAdige2024/laives_weather.csv
# Processing weather data for municipality: lajen (46.6122023477098, 11.597114374080435)...
# Weather data for lajen saved to WeatherTrentinoAltoAdige2024/lajen_weather.csv
# Processing weather data for municipality: lana (46.60365652324663, 11.144250547262429)...
# Weather data for lana saved to WeatherTrentinoAltoAdige2024/lana_weather.csv
# Processing weather data for municipality: lana (46.60365652324663, 11.144250547262429)...
# Weather data for lana saved to WeatherTrentinoAltoAdige2024/lana_weather.csv
# Processing weather data for municipality: lana (46.60365652324663, 11.144250547262429)...
# Weather data for lana saved to WeatherTrentinoAltoAdige2024/lana_weather.csv
# Processing weather data for municipality: lana (46.60365652324663, 11.144250547262429)...
# Weather data for lana saved to WeatherTrentinoAltoAdige2024/lana_weather.csv
# Processing weather data for municipality: lana (46.60365652324663, 11.144250547262429)...
# Weather data for lana saved to WeatherTrentinoAltoAdige2024/lana_weather.csv
# Processing weather data for municipality: lana (46.60365652324663, 11.144250547262429)...
# Weather data for lana saved to WeatherTrentinoAltoAdige2024/lana_weather.csv
# Processing weather data for municipality: lana (46.60365652324663, 11.144250547262429)...
# Weather data for lana saved to WeatherTrentinoAltoAdige2024/lana_weather.csv
# Processing weather data for municipality: lana (46.60365652324663, 11.144250547262429)...
# Weather data for lana saved to WeatherTrentinoAltoAdige2024/lana_weather.csv
# Processing weather data for municipality: lardaro (45.9828, 10.6386)...
# Weather data for lardaro saved to WeatherTrentinoAltoAdige2024/lardaro_weather.csv
# Processing weather data for municipality: lasa (46.606038126534635, 10.668992009919512)...
# Weather data for lasa saved to WeatherTrentinoAltoAdige2024/lasa_weather.csv
# Processing weather data for municipality: lasa (46.606038126534635, 10.668992009919512)...
# Weather data for lasa saved to WeatherTrentinoAltoAdige2024/lasa_weather.csv
# Processing weather data for municipality: lasino (46.0333, 10.9667)...
# Weather data for lasino saved to WeatherTrentinoAltoAdige2024/lasino_weather.csv
# Processing weather data for municipality: latsch (46.60094617858487, 10.85757429413232)...
# Weather data for latsch saved to WeatherTrentinoAltoAdige2024/latsch_weather.csv
# Processing weather data for municipality: lauregno (46.474522573184906, 11.05140815462748)...
# Weather data for lauregno saved to WeatherTrentinoAltoAdige2024/lauregno_weather.csv
# Processing weather data for municipality: laurein (46.474522573184906, 11.05140815462748)...
# Weather data for laurein saved to WeatherTrentinoAltoAdige2024/laurein_weather.csv
# Processing weather data for municipality: lavarone (45.94095494559087, 11.286622364817848)...
# Weather data for lavarone saved to WeatherTrentinoAltoAdige2024/lavarone_weather.csv
# Processing weather data for municipality: lavis (46.151504134934385, 11.103645673703465)...
# Weather data for lavis saved to WeatherTrentinoAltoAdige2024/lavis_weather.csv
# Processing weather data for municipality: ledro (45.88512365357851, 10.719250517561129)...
# Weather data for ledro saved to WeatherTrentinoAltoAdige2024/ledro_weather.csv
# Processing weather data for municipality: ledro (pieve di ledro) (45.8717, 10.7413)...
# Weather data for ledro (pieve di ledro) saved to WeatherTrentinoAltoAdige2024/ledro _pieve di ledro__weather.csv
# Processing weather data for municipality: leifers (46.438480091452206, 11.344890307571587)...
# Weather data for leifers saved to WeatherTrentinoAltoAdige2024/leifers_weather.csv
# Processing weather data for municipality: levico terme (45.996519909741714, 11.330000398418758)...
# Weather data for levico terme saved to WeatherTrentinoAltoAdige2024/levico terme_weather.csv
# Processing weather data for municipality: livo (46.421849398912954, 11.005470274544225)...
# Weather data for livo saved to WeatherTrentinoAltoAdige2024/livo_weather.csv
# Processing weather data for municipality: lona-lases (46.167452315324894, 11.279829986651537)...
# Weather data for lona-lases saved to WeatherTrentinoAltoAdige2024/lona-lases_weather.csv
# Processing weather data for municipality: lona-lases (46.167452315324894, 11.279829986651537)...
# Weather data for lona-lases saved to WeatherTrentinoAltoAdige2024/lona-lases_weather.csv
# Processing weather data for municipality: lusen (46.73297003682968, 11.771675659135887)...
# Weather data for lusen saved to WeatherTrentinoAltoAdige2024/lusen_weather.csv
# Processing weather data for municipality: lusern (45.9564, 11.3249)...
# Weather data for lusern saved to WeatherTrentinoAltoAdige2024/lusern_weather.csv
# Processing weather data for municipality: luserna (45.9564, 11.3249)...
# Weather data for luserna saved to WeatherTrentinoAltoAdige2024/luserna_weather.csv
# ...
# Processing weather data for municipality: terre dadige (46.161339868529375, 11.068325745786774)...
# Weather data for terre dadige saved to WeatherTrentinoAltoAdige2024/terre dadige_weather.csv
# Processing weather data for municipality: terres (46.35, 11.0667)...
# Weather data for terres saved to WeatherTrentinoAltoAdige2024/terres_weather.csv
# Processing weather data for municipality: terzolas (46.35959436104659, 10.931382269846791)...
# Weather data for terzolas saved to WeatherTrentinoAltoAdige2024/terzolas_weather.csv
# Processing weather data for municipality: tesero (46.28758714798504, 11.519636281638576)...
# Weather data for tesero saved to WeatherTrentinoAltoAdige2024/tesero_weather.csv
# Processing weather data for municipality: tesimo (46.55076835933028, 11.149426673204465)...
# Weather data for tesimo saved to WeatherTrentinoAltoAdige2024/tesimo_weather.csv
# Processing weather data for municipality: tiarno di sopra (45.9, 10.7)...
# Weather data for tiarno di sopra saved to WeatherTrentinoAltoAdige2024/tiarno di sopra_weather.csv
# Processing weather data for municipality: tiarno di sotto (45.8854, 10.7117)...
# Weather data for tiarno di sotto saved to WeatherTrentinoAltoAdige2024/tiarno di sotto_weather.csv
# Processing weather data for municipality: tiers (46.47473829958982, 11.581302342904667)...
# Weather data for tiers saved to WeatherTrentinoAltoAdige2024/tiers_weather.csv
# Processing weather data for municipality: tione di trento (46.02388229041673, 10.716923394733172)...
# Weather data for tione di trento saved to WeatherTrentinoAltoAdige2024/tione di trento_weather.csv
# Processing weather data for municipality: tires (46.47473829958982, 11.581302342904667)...
# Weather data for tires saved to WeatherTrentinoAltoAdige2024/tires_weather.csv
# Processing weather data for municipality: tires (46.47473829958982, 11.581302342904667)...
# Weather data for tires saved to WeatherTrentinoAltoAdige2024/tires_weather.csv
# Processing weather data for municipality: tirol (46.7140526084415, 11.12852371925764)...
# Weather data for tirol saved to WeatherTrentinoAltoAdige2024/tirol_weather.csv
# Processing weather data for municipality: tirolo (46.7140526084415, 11.12852371925764)...
# Weather data for tirolo saved to WeatherTrentinoAltoAdige2024/tirolo_weather.csv
# Processing weather data for municipality: tirolo (46.7140526084415, 11.12852371925764)...
# Weather data for tirolo saved to WeatherTrentinoAltoAdige2024/tirolo_weather.csv
# Processing weather data for municipality: tisens (46.55076835933028, 11.149426673204465)...
# Weather data for tisens saved to WeatherTrentinoAltoAdige2024/tisens_weather.csv
# Processing weather data for municipality: toblach (46.69697413119851, 12.237376180868647)...
# Weather data for toblach saved to WeatherTrentinoAltoAdige2024/toblach_weather.csv
# Processing weather data for municipality: toblino (46.05, 11.0167)...
# Weather data for toblino saved to WeatherTrentinoAltoAdige2024/toblino_weather.csv
# Processing weather data for municipality: ton (46.26314878571555, 11.097019606485423)...
# Weather data for ton saved to WeatherTrentinoAltoAdige2024/ton_weather.csv
# Processing weather data for municipality: tonadico (46.1693, 11.8419)...
# Weather data for tonadico saved to WeatherTrentinoAltoAdige2024/tonadico_weather.csv
# Processing weather data for municipality: torcegno (46.098756941651054, 11.417721826084009)...
# Weather data for torcegno saved to WeatherTrentinoAltoAdige2024/torcegno_weather.csv
# Processing weather data for municipality: trambileno (45.83584307523651, 11.128476087558896)...
# Weather data for trambileno saved to WeatherTrentinoAltoAdige2024/trambileno_weather.csv
# Processing weather data for municipality: tramin an der weinstrae (46.34328227119103, 11.236109613258895)...
# Weather data for tramin an der weinstrae saved to WeatherTrentinoAltoAdige2024/tramin an der weinstrae_weather.csv
# Processing weather data for municipality: transacqua (46.1718, 11.8495)...
# Weather data for transacqua saved to WeatherTrentinoAltoAdige2024/transacqua_weather.csv
# Processing weather data for municipality: tre ville (46.156859845540495, 10.832103779624113)...
# Weather data for tre ville saved to WeatherTrentinoAltoAdige2024/tre ville_weather.csv
# Processing weather data for municipality: trento (46.0615307893722, 11.110755411820012)...
# Weather data for trento saved to WeatherTrentinoAltoAdige2024/trento_weather.csv
# Processing weather data for municipality: tres (46.3667, 11.1333)...
# Weather data for tres saved to WeatherTrentinoAltoAdige2024/tres_weather.csv
# Processing weather data for municipality: trodena nel parco naturale (46.315296875040794, 11.356343345620257)...
# Weather data for trodena nel parco naturale saved to WeatherTrentinoAltoAdige2024/trodena nel parco naturale_weather.csv
# Processing weather data for municipality: trodena nel parco naturale (46.31, 11.3667)...
# Weather data for trodena nel parco naturale saved to WeatherTrentinoAltoAdige2024/trodena nel parco naturale_weather.csv
# Processing weather data for municipality: truden im naturpark (46.31, 11.3667)...
# Weather data for truden im naturpark saved to WeatherTrentinoAltoAdige2024/truden im naturpark_weather.csv
# Processing weather data for municipality: tscherms (46.63375781246668, 11.136403050510523)...
# Weather data for tscherms saved to WeatherTrentinoAltoAdige2024/tscherms_weather.csv
# Processing weather data for municipality: tubre (46.658052235140616, 10.443987684334706)...
# Weather data for tubre saved to WeatherTrentinoAltoAdige2024/tubre_weather.csv
# Processing weather data for municipality: tuenno (46.35, 11.05)...
# Weather data for tuenno saved to WeatherTrentinoAltoAdige2024/tuenno_weather.csv
# Processing weather data for municipality: ulten (46.510569434455256, 10.906526114347034)...
# Weather data for ulten saved to WeatherTrentinoAltoAdige2024/ulten_weather.csv
# Processing weather data for municipality: ultimo (46.510569434455256, 10.906526114347034)...
# Weather data for ultimo saved to WeatherTrentinoAltoAdige2024/ultimo_weather.csv
# Processing weather data for municipality: ultimo (46.510569434455256, 10.906526114347034)...
# Weather data for ultimo saved to WeatherTrentinoAltoAdige2024/ultimo_weather.csv
# Processing weather data for municipality: unsere liebe frau im walde-st. felix (46.50883455076642, 11.131653482240315)...
# Weather data for unsere liebe frau im walde-st. felix saved to WeatherTrentinoAltoAdige2024/unsere liebe frau im walde-st. felix_weather.csv
# Processing weather data for municipality: vadena (46.394751926846354, 11.295125867367394)...
# Weather data for vadena saved to WeatherTrentinoAltoAdige2024/vadena_weather.csv
# Processing weather data for municipality: vadena (46.394751926846354, 11.295125867367394)...
# Weather data for vadena saved to WeatherTrentinoAltoAdige2024/vadena_weather.csv
# Processing weather data for municipality: vahrn (46.74573481802748, 11.570147130897222)...
# Weather data for vahrn saved to WeatherTrentinoAltoAdige2024/vahrn_weather.csv
# Processing weather data for municipality: val di vizze (46.95084875284459, 11.584928095308973)...
# Weather data for val di vizze saved to WeatherTrentinoAltoAdige2024/val di vizze_weather.csv
# Processing weather data for municipality: val di vizze (46.95084875284459, 11.584928095308973)...
# Weather data for val di vizze saved to WeatherTrentinoAltoAdige2024/val di vizze_weather.csv
# Processing weather data for municipality: valda (46.2, 11.3)...
# Weather data for valda saved to WeatherTrentinoAltoAdige2024/valda_weather.csv
# Processing weather data for municipality: valdaone (46.01637758883958, 10.545096522864917)...
# Weather data for valdaone saved to WeatherTrentinoAltoAdige2024/valdaone_weather.csv
# Processing weather data for municipality: valdaora (46.740661051891166, 12.023798123293153)...
# Weather data for valdaora saved to WeatherTrentinoAltoAdige2024/valdaora_weather.csv
# Processing weather data for municipality: valdaora (46.740661051891166, 12.023798123293153)...
# Weather data for valdaora saved to WeatherTrentinoAltoAdige2024/valdaora_weather.csv
# Processing weather data for municipality: valfloriana (46.21766987645526, 11.383959358486653)...
# Weather data for valfloriana saved to WeatherTrentinoAltoAdige2024/valfloriana_weather.csv
# Processing weather data for municipality: vallarsa (45.78252860380218, 11.119370317563874)...
# Weather data for vallarsa saved to WeatherTrentinoAltoAdige2024/vallarsa_weather.csv
# Processing weather data for municipality: valle aurina (46.98816745720802, 11.94342284351528)...
# Weather data for valle aurina saved to WeatherTrentinoAltoAdige2024/valle aurina_weather.csv
# Processing weather data for municipality: valle aurina (46.98816745720802, 11.94342284351528)...
# Weather data for valle aurina saved to WeatherTrentinoAltoAdige2024/valle aurina_weather.csv
# Processing weather data for municipality: valle di casies (46.820949309310905, 12.225261029082036)...
# Weather data for villa rendena saved to WeatherTrentinoAltoAdige2024/villa rendena_weather.csv
# Processing weather data for municipality: villabassa (46.73501600045775, 12.165685254480437)...
# Weather data for villabassa saved to WeatherTrentinoAltoAdige2024/villabassa_weather.csv
# Processing weather data for municipality: villabassa (46.73501600045775, 12.165685254480437)...
# Weather data for villabassa saved to WeatherTrentinoAltoAdige2024/villabassa_weather.csv
# Processing weather data for municipality: villanders (46.64498010864615, 11.485128946208969)...
# Weather data for villanders saved to WeatherTrentinoAltoAdige2024/villanders_weather.csv
# Processing weather data for municipality: villandro (46.64498010864615, 11.485128946208969)...
# Weather data for villandro saved to WeatherTrentinoAltoAdige2024/villandro_weather.csv
# Processing weather data for municipality: ville danaunia (46.27718358691969, 10.96191978246088)...
# Weather data for ville danaunia saved to WeatherTrentinoAltoAdige2024/ville danaunia_weather.csv
# Processing weather data for municipality: ville di fiemme (46.317570655802214, 11.448899424596698)...
# Weather data for ville di fiemme saved to WeatherTrentinoAltoAdige2024/ville di fiemme_weather.csv
# Processing weather data for municipality: villno (46.63948488798519, 11.713404571230734)...
# Weather data for villno saved to WeatherTrentinoAltoAdige2024/villno_weather.csv
# Processing weather data for municipality: vintl (46.886553345266066, 11.70216313876594)...
# Weather data for vintl saved to WeatherTrentinoAltoAdige2024/vintl_weather.csv
# Processing weather data for municipality: vipiteno (46.914184068512824, 11.42248237552417)...
# Weather data for vipiteno saved to WeatherTrentinoAltoAdige2024/vipiteno_weather.csv
# Processing weather data for municipality: vipiteno (46.914184068512824, 11.42248237552417)...
# Weather data for vipiteno saved to WeatherTrentinoAltoAdige2024/vipiteno_weather.csv
# Processing weather data for municipality: volano (45.91302949606486, 11.081858346789492)...
# Weather data for volano saved to WeatherTrentinoAltoAdige2024/volano_weather.csv
# Processing weather data for municipality: vols am schlern (46.50802705505989, 11.520169281625666)...
# Weather data for vols am schlern saved to WeatherTrentinoAltoAdige2024/vols am schlern_weather.csv
# Processing weather data for municipality: voran (46.62164280708838, 11.24650247966236)...
# Weather data for voran saved to WeatherTrentinoAltoAdige2024/voran_weather.csv
# Processing weather data for municipality: waidbruck (46.59216560559299, 11.538488450201916)...
# Weather data for waidbruck saved to WeatherTrentinoAltoAdige2024/waidbruck_weather.csv
# Processing weather data for municipality: welsberg-taisten (46.7412, 12.1097)...
# Weather data for welsberg-taisten saved to WeatherTrentinoAltoAdige2024/welsberg-taisten_weather.csv
# Processing weather data for municipality: welschnofen (46.42397674047654, 11.564302950692037)...
# Weather data for welschnofen saved to WeatherTrentinoAltoAdige2024/welschnofen_weather.csv
# Processing weather data for municipality: wengen (46.6492925221126, 11.93849485863982)...
# Weather data for wengen saved to WeatherTrentinoAltoAdige2024/wengen_weather.csv
# Processing weather data for municipality: wolkenstein in groden (46.55462080101532, 11.781387543008886)...
# Weather data for wolkenstein in groden saved to WeatherTrentinoAltoAdige2024/wolkenstein in groden_weather.csv
# Processing weather data for municipality: ziano di fiemme (46.26983191708317, 11.582863889940413)...
# Weather data for ziano di fiemme saved to WeatherTrentinoAltoAdige2024/ziano di fiemme_weather.csv
